# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_34.csv')

# %%
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
sns.heatmap(data.isnull(), cmap='viridis')
# Out:
# <Axes: >

# %%
data=data.dropna()

# %%
data.shape
# Out:
# (264, 67)

# %%
years=data.columns[4:]

# %%
years=years.astype(int)

# %%
years=np.array(years)

# %%
years=years.reshape(-1,1)

# %%
population=data.iloc[0,4:]

# %%
plt.figure(figsize=(12,8))
plt.plot(year, population, marker='o', linestyle='-', markerfacecolor='red')
plt.title('World Population (1960 - 2020)', fontsize=12, color='blue')
plt.xlabel('Year', fontsize=12, color='blue')
plt.ylabel('Population', fontsize=12, color='blue')
plt.grid(True)
plt.show()

# %%
country='India'
india=data[data['Country Name']==country]

# %%
years=india.columns[4:]

# %%
india_population=india.iloc[0, 4:]

# %%
year=np.array(years)

# %%
year=year.reshape(-1,1)

# %%
year=year.astype(int)

# %%
usa_population=np.array(data[data['Country Name']=='United States'].iloc[:,4:])
usa_population=usa_population.astype(int).reshape(-1,1)

# %%
plt.figure(figsize=(10,8))
plt.plot(year, india_population, marker='o', linestyle='-', markerfacecolor='red', label='India')
plt.plot(year, china_population, marker='*', linestyle='-', markerfacecolor='yellow', label='China')
plt.plot(year, usa_population, marker='o', linestyle='-', markerfacecolor='blue', label='USA') 
plt.xlabel('Years', color='blue', fontsize=12)
plt.ylabel('Population', color='blue', fontsize=12)
plt.title("Population Comparison", color='blue', fontsize=12)  
plt.ticklabel_format(style='plain', axis='y') 
plt.legend()
plt.grid(True)
plt.show()

# %%
china=data[data['Country Name']=='China']
china_population=china.iloc[:,4:]

# %%
china_population=np.array(china_population)
china_population=china_population.astype(int)
china_population=china_population.reshape(-1,1)

# %%
country=data.iloc[:,0]

# %%
pop_1960=data.iloc[:,4]

# %%
bubble_sizes = [100 for _ in range(len(country.head(20)))]  # Placeholder sizes for illustration purposes

# Plotting
plt.figure(figsize=(10, 6))

# Plot bubble chart
plt.scatter(country.head(20), pop_1960.head(20), s=bubble_sizes, alpha=0.5)

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Population in 1960')
plt.title('Bubble Chart of Population in 1960')

# Rotating x-axis labels for better readability (optional)
plt.xticks(rotation=90)
plt.ticklabel_format(style='plain', axis='y') 
# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()
